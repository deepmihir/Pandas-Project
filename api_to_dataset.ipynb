# %%
import pandas as pd, requests

# %%
url = 'https://restcountries.com/v3.1/all'

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
df = pd.DataFrame(data)
df
# Out:
#                                                   name  \
# 0    {'common': 'Guatemala', 'official': 'Republic ...
# 1    {'common': 'Singapore', 'official': 'Republic ...
# 2    {'common': 'Bosnia and Herzegovina', 'official...
# 3    {'common': 'Maldives', 'official': 'Republic o...
# 4    {'common': 'Latvia', 'official': 'Republic of ...
# ..                                                 ...
# 245  {'common': 'South Korea', 'official': 'Republi...
# 246  {'common': 'Denmark', 'official': 'Kingdom of ...
# 247  {'common': 'Oman', 'official': 'Sultanate of O...
# 248  {'common': 'Pitcairn Islands', 'official': 'Pi...
# 249  {'common': 'Senegal', 'official': 'Republic of...
#
#                            tld cca2 ccn3 cca3 cioc independent  \
# 0                        [.gt]   GT  320  GTM  GUA        True
# 1    [.sg, .新加坡, .சிங்கப்பூர்]   SG  702  SGP  SGP        True
# 2                        [.ba]   BA  070  BIH  BIH        True
# 3                        [.mv]   MV  462  MDV  MDV        True
# 4                        [.lv]   LV  428  LVA  LAT        True
# ..                         ...  ...  ...  ...  ...         ...
# 245                 [.kr, .한국]   KR  410  KOR  KOR        True
# 246                      [.dk]   DK  208  DNK  DEN        True
# 247                      [.om]   OM  512  OMN  OMA        True
# 248                      [.pn]   PN  612  PCN  NaN       False
# 249                      [.sn]   SN  686  SEN  SEN        True
#
#                   status  unMember  \
# 0    officially-assigned      True
# 1    officially-assigned      True
# 2    officially-assigned      True
# 3    officially-assigned      True
# 4    officially-assigned      True
# ..                   ...       ...
# 245  officially-assigned      True
# 246  officially-assigned      True
# 247  officially-assigned      True
# 248  officially-assigned     False
# 249  officially-assigned      True
#
#                                             currencies  ...            gini  \
# 0    {'GTQ': {'name': 'Guatemalan quetzal', 'symbol...  ...  {'2014': 48.3}
# 1    {'SGD': {'name': 'Singapore dollar', 'symbol':...  ...             NaN
# 2    {'BAM': {'name': 'Bosnia and Herzegovina conve...  ...  {'2011': 33.0}
# 3    {'MVR': {'name': 'Maldivian rufiyaa', 'symbol'...  ...  {'2016': 31.3}
# 4             {'EUR': {'name': 'Euro', 'symbol': '€'}}  ...  {'2018': 35.1}
# ..                                                 ...  ...             ...
# 245  {'KRW': {'name': 'South Korean won', 'symbol':...  ...  {'2016': 31.4}
# 246  {'DKK': {'name': 'Danish krone', 'symbol': 'kr'}}  ...  {'2018': 28.2}
# 247  {'OMR': {'name': 'Omani rial', 'symbol': 'ر.ع.'}}  ...             NaN
# 248  {'NZD': {'name': 'New Zealand dollar', 'symbol...  ...             NaN
# 249  {'XOF': {'name': 'West African CFA franc', 'sy...  ...  {'2011': 40.3}
#
#     fifa                                  car  \
# 0    GUA  {'signs': ['GCA'], 'side': 'right'}
# 1    SIN   {'signs': ['SGP'], 'side': 'left'}
# 2    BIH  {'signs': ['BIH'], 'side': 'right'}
# 3    MDV    {'signs': ['MV'], 'side': 'left'}
# 4    LVA   {'signs': ['LV'], 'side': 'right'}
# ..   ...                                  ...
# 245  KOR  {'signs': ['ROK'], 'side': 'right'}
# 246  DEN   {'signs': ['DK'], 'side': 'right'}
# 247  OMA   {'signs': ['OM'], 'side': 'right'}
# 248  NaN    {'signs': ['GB'], 'side': 'left'}
# 249  SEN   {'signs': ['SN'], 'side': 'right'}
#
#                                              timezones       continents  \
# 0                                          [UTC-06:00]  [North America]
# 1                                          [UTC+08:00]           [Asia]
# 2                                          [UTC+01:00]         [Europe]
# 3                                          [UTC+05:00]           [Asia]
# 4                                          [UTC+02:00]         [Europe]
# ..                                                 ...              ...
# 245                                        [UTC+09:00]           [Asia]
# 246  [UTC-04:00, UTC-03:00, UTC-01:00, UTC, UTC+01:00]         [Europe]
# 247                                        [UTC+04:00]           [Asia]
# 248                                        [UTC-08:00]        [Oceania]
# 249                                              [UTC]         [Africa]
#
#                                                  flags  \
# 0    {'png': 'https://flagcdn.com/w320/gt.png', 'sv...
# 1    {'png': 'https://flagcdn.com/w320/sg.png', 'sv...
# 2    {'png': 'https://flagcdn.com/w320/ba.png', 'sv...
# 3    {'png': 'https://flagcdn.com/w320/mv.png', 'sv...
# 4    {'png': 'https://flagcdn.com/w320/lv.png', 'sv...
# ..                                                 ...
# 245  {'png': 'https://flagcdn.com/w320/kr.png', 'sv...
# 246  {'png': 'https://flagcdn.com/w320/dk.png', 'sv...
# 247  {'png': 'https://flagcdn.com/w320/om.png', 'sv...
# 248  {'png': 'https://flagcdn.com/w320/pn.png', 'sv...
# 249  {'png': 'https://flagcdn.com/w320/sn.png', 'sv...
#
#                                             coatOfArms startOfWeek  \
# 0    {'png': 'https://mainfacts.com/media/images/co...      monday
# 1    {'png': 'https://mainfacts.com/media/images/co...      monday
# 2    {'png': 'https://mainfacts.com/media/images/co...      monday
# 3    {'png': 'https://mainfacts.com/media/images/co...      sunday
# 4    {'png': 'https://mainfacts.com/media/images/co...      monday
# ..                                                 ...         ...
# 245  {'png': 'https://mainfacts.com/media/images/co...      monday
# 246  {'png': 'https://mainfacts.com/media/images/co...      monday
# 247  {'png': 'https://mainfacts.com/media/images/co...      sunday
# 248                                                 {}      monday
# 249  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                        capitalInfo  \
# 0      {'latlng': [14.62, -90.52]}
# 1       {'latlng': [1.28, 103.85]}
# 2       {'latlng': [43.87, 18.42]}
# 3        {'latlng': [4.17, 73.51]}
# 4        {'latlng': [56.95, 24.1]}
# ..                             ...
# 245    {'latlng': [37.55, 126.98]}
# 246     {'latlng': [55.67, 12.58]}
# 247     {'latlng': [23.62, 58.58]}
# 248  {'latlng': [-25.07, -130.08]}
# 249    {'latlng': [14.73, -17.63]}
#
#                                             postalCode
# 0            {'format': '#####', 'regex': '^(\d{5})$'}
# 1           {'format': '######', 'regex': '^(\d{6})$'}
# 2            {'format': '#####', 'regex': '^(\d{5})$'}
# 3            {'format': '#####', 'regex': '^(\d{5})$'}
# 4    {'format': 'LV-####', 'regex': '^(?:LV)*(\d{4}...
# ..                                                 ...
# 245  {'format': 'SEOUL ###-###', 'regex': '^(?:SEOU...
# 246           {'format': '####', 'regex': '^(\d{4})$'}
# 247            {'format': '###', 'regex': '^(\d{3})$'}
# 248                                                NaN
# 249          {'format': '#####', 'regex': '^(\d{5})$'}
#
# [250 rows x 35 columns]

# %%
from pandas_profiling import ProfileReport
df = pd.read_csv('D:\pandas handsOn\Datasets\titanic.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 df = pd.read_csv('D:\pandas handsOn\Datasets\titanic.csv')
#       3 df
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
